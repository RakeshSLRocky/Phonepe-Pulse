# %%
# importing required libraries
import os
from git import Repo
import pandas as pd
import json
import csv

# Funtion to clone the data from phonepe github repository
def clone():

    repo_url = "https://github.com/PhonePe/pulse.git" #path of repo need to be cloned
    clone_path = r"D:\Phonepe_pluse"   #path where to store

    if not os.path.exists(clone_path):
        os.makedirs(clone_path)

    Repo.clone_from(repo_url, clone_path)
# calling the function to clone
clone()

# %%
import os
from git import Repo
import pandas as pd
import json
import csv
# Extracting Aggregated Transaction data from the cloned path
# path of aggregated transaction data
path="D://phonepe//pulse//data//aggregated//transaction//country//india//state"
Agg_state_list=os.listdir(path) #getting the state folders using os module
# Agg_state_list
# getting the data of state, year, quater, transactn type
clm={'State':[], 'Year':[],'Quarter':[],'Transaction_Type':[], 'Transaction_Count':[], 'Transaction_Amount':[]}
for i in Agg_state_list:
    p_i=path+"//"+i+"//"
    Agg_yr=os.listdir(p_i)    
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_Type'].append(Name)
              clm['Transaction_Count'].append(count)
              clm['Transaction_Amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quarter'].append(int(k.strip('.json')))
#creating a dataframe
# clm
Agg_Trans=pd.DataFrame(clm)
Agg_Trans.to_csv('aggregated_transaction.csv',index=False)

# %%
# Extracting Aggregated user data from the cloned path
# path of aggregated user data
path2="D://Phonepe_pluse//data//aggregated//user//country//india//state"
user_list = os.listdir(path2)
col2 = {'State': [], 'Year': [], 'Quarter': [], 'Brands': [], 'Count': [],'Percentage': []}
col12 = {'Year' : [], 'Quarter' : [], 'RegisteredUser' : [], 'AppOpens' : []}
for i in user_list:
    p_i = path2 +"//"+ i + "//"
    Agg_yr = os.listdir(p_i)

    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)

        for k in Agg_yr_list:
            p_k = p_j + k
            # print(p_k)
            Data = open(p_k, 'r')
            B = json.load(Data)
            try:
                for w in B["data"]["usersByDevice"]:
                    brand_name = w["brand"]
                    count_ = w["count"]
                    ALL_percentage = w["percentage"]
                    col2["Brands"].append(brand_name)
                    col2["Count"].append(count_)
                    col2["Percentage"].append(ALL_percentage)
                    col2["State"].append(i)
                    col2["Year"].append(j)
                    col2["Quarter"].append(int(k.strip('.json')))
            except:
                pass

for i in user_list:
    p_i = path2 +"//"+ i + "//"
    Agg_yr = os.listdir(p_i)

    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)

        for k in Agg_yr_list:
            p_k = p_j + k
            # print(p_k)
            Data = open(p_k, 'r')
            B = json.load(Data)
            for r in B:
                user = B["data"]["aggregated"]["registeredUsers"]
                app = B["data"]["aggregated"]["appOpens"]
                col12["Year"].append(j)
                col12["Quarter"].append(int(k.strip('.json')))
                col12["RegisteredUser"].append(user)
                col12["AppOpens"].append(app)
                    
                    
                    
df_mobileBrand = pd.DataFrame(col2)
df_mobileBrand.to_csv('aggregateduser_mobile.csv',index=False)
df_agg_user1 = pd.DataFrame(col12)
df_agg_user1.to_csv('aggregated_user.csv', index = False)

# %%
# path of map transactions
path3="D://Phonepe_pluse//data//map//transaction//hover//country//india//state"

hover_list = os.listdir(path3)

col3 = {'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Count': [],
        'amount': []}
for i in hover_list:
    p_i = path3 +"//"+ i + "//"
    Agg_yr = os.listdir(p_i)

    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)

        for k in Agg_yr_list:
            p_k = p_j + k
            # print(p_k)
            Data = open(p_k, 'r')
            C = json.load(Data)
            for x in C["data"]["hoverDataList"]:
                District = x["name"]
                count = x["metric"][0]["count"]
                amount = x["metric"][0]["amount"]
                col3["District"].append(District)
                col3["Count"].append(count)
                col3["amount"].append(amount)
                col3['State'].append(i)
                col3['Year'].append(j)
                col3['Quarter'].append(int(k.strip('.json')))
df_map_transaction = pd.DataFrame(col3)
df_map_transaction.to_csv('map_transaction.csv',index=False)

# %%
# path of map users
path4="D://Phonepe_pluse//data//map//user//hover//country//india//state"

map_list = os.listdir(path4)

col4 = {"State": [], "Year": [], "Quarter": [], "District": [],
        "Registered_User": [], "AppOnes" : []}
for i in map_list:
    p_i = path4 + "//"+i + "//"
    Agg_yr = os.listdir(p_i)

    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)

        for k in Agg_yr_list:
            p_k = p_j + k
            # print(p_k)
            Data = open(p_k, 'r')
            D = json.load(Data)

            for u in D["data"]["hoverData"].items():
                district = u[0]
                registereduser = u[1]["registeredUsers"]
                appopens = u[1]["appOpens"]
                col4["District"].append(district)
                col4["Registered_User"].append(registereduser)
                col4["AppOnes"].append(appopens)
                col4['State'].append(i)
                col4['Year'].append(j)
                col4['Quarter'].append(int(k.strip('.json')))
df_map_user = pd.DataFrame(col4)
df_map_user.to_csv('map_user.csv',index=False)

# %%
# Path for top transaction 

path5="D://Phonepe_pluse//data//top//transaction//country//india//state"
TOP_list = os.listdir(path5)

col5 = {'Entity_Name': [], 'Year': [], 'Quarter': [], 'Type': [], 'Count': [],
        'Amount': [], 'State' : []}


for i in TOP_list:
    p_i = path5 + "//" + i + "//"
    Agg_yr = os.listdir(p_i)

    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)

        for k in Agg_yr_list:
            p_k = p_j + k
            # print(p_k)
            Data = open(p_k, 'r')
            E = json.load(Data)
            for z in E['data']['pincodes']:
                Name = 'Pincode'
                name = z['entityName']
                count = z['metric']['count']
                amount = z['metric']['amount']
                col5['State'].append(i)
                col5['Type'].append(Name)
                col5['Entity_Name'].append(name)
                col5['Count'].append(count)
                col5['Amount'].append(amount)
                col5['Year'].append(j)
                col5['Quarter'].append(int(k.strip('.json')))
                
            for x in E['data']['districts']:
                Name = 'District'
                name = x['entityName']
                count = x['metric']['count']
                amount = x['metric']['amount']
                col5['State'].append(i)
                col5['Type'].append(Name)
                col5['Entity_Name'].append(name)
                col5['Count'].append(count)
                col5['Amount'].append(amount)
                col5['Year'].append(j)
                col5['Quarter'].append(int(k.strip('.json')))
                
df_top_transaction = pd.DataFrame(col5)
df_top_transaction.to_csv('top_transaction.csv',index=False)

# %%
# Path for top user data

path6="D://Phonepe_pluse//data//top//user//country//india/state"
USER_list = os.listdir(path6)

TOP_list = os.listdir(path5)

col6 = {'Entity_Name': [], 'Year': [], 'Quarter': [], 'Type': [], 'Registered_User': [], 'State' : []}


for i in TOP_list:
    p_i = path6 + "//" + i + "//"
    Agg_yr = os.listdir(p_i)

    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)

        for k in Agg_yr_list:
            p_k = p_j + k
            # print(p_k)
            Data = open(p_k, 'r')
            E = json.load(Data)
            for z in E['data']['pincodes']:
                Name = 'Pincode'
                name = z['name']
                registeredUser = z['registeredUsers']
                col6['State'].append(i)
                col6['Type'].append(Name)
                col6['Entity_Name'].append(name)
                col6['Registered_User'].append(registeredUser)
                col6['Year'].append(j)
                col6['Quarter'].append(int(k.strip('.json')))
                
            for x in E['data']['districts']:
                Name = 'District'
                name = x['name']
                registeredUser = x['registeredUsers']
                col6['State'].append(i)
                col6['Type'].append(Name)
                col6['Entity_Name'].append(name)
                col6['Registered_User'].append(registeredUser)
                col6['Year'].append(j)
                col6['Quarter'].append(int(k.strip('.json')))
                
df_topuser = pd.DataFrame(col6)
df_topuser.to_csv('top_user.csv',index=False)

# %%
# Transforming Aggregated transaction data to required format

df_trans = pd.read_csv('aggregated_transaction.csv')

df_t = df_trans
col32 = {'Year' : [], 'Quarter' : [], 'Transaction_Type' : [], 'Transaction_Count' : [], 'Transaction_Amount' : []}

year = [2018, 2019, 2020, 2021, 2022]
Quarter = [1,2,3,4]
Transaction_Type = ['Recharge & bill payments', 'Peer-to-peer payments', 'Merchant payments', 'Financial Services', 'Others'  ]

for i in year:
    for j in Quarter:
        for k in Transaction_Type:
            a = df_t.loc[(df_t["Year"] == i) & (df_t["Quarter"] == j) & (df_t["Transaction_Type"] == k), 'Transaction_Count'].sum()
            b = df_t.loc[(df_t["Year"] == i) & (df_t["Quarter"] == j) & (df_t["Transaction_Type"] == k),'Transaction_Amount'].sum()
            col32['Year'].append(i),
            col32['Quarter'].append(j),
            col32['Transaction_Type'].append(k)
            col32['Transaction_Count'].append(a)
            col32['Transaction_Amount'].append(b)
            
df_aggtrans =pd.DataFrame(col32)
df_aggtrans.to_csv('aggtrans.csv', index = False)

# %%
# Transforming Aggregated user data to required format

df_agg_user = pd.read_csv('aggregated_user.csv')
cola = { 'Year':[], 'Quarter':[], 'RegisteredUser': [], 'AppOpens': [] }

year = [2018, 2019, 2020, 2021, 2022]
Quarter = [1,2,3,4]

for i in year:
    for j in Quarter:
        a = df_agg_user.loc[(df_agg_user["Year"] == i) & (df_agg_user["Quarter"] == j),'RegisteredUser'].sum()
        b = df_agg_user.loc[(df_agg_user["Year"] == i) & (df_agg_user["Quarter"] == j),'AppOpens'].sum()
        cola['Year'].append(i)
        cola['Quarter'].append(j)
        cola['RegisteredUser'].append(a)
        cola['AppOpens'].append(b)

df_agguserr = pd.DataFrame(cola)
df_agguserr.to_csv('agguser.csv', index =False)

# %%
# Transforming map transaction data to required format

df_maptrans = pd.read_csv('map_transaction.csv')

colb = {'Year' : [], 'Quarter' : [], 'State' : [], 'Count' : [], 'Amount' : []}

year = [2018, 2019, 2020, 2021, 2022]
Quarter = [1,2,3,4]
states = ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh',
                  'assam', 'bihar', 'chandigarh', 'chhattisgarh',
                  'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat',
                  'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand',
                  'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh',
                  'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland',
                  'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
                  'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh',
                  'uttarakhand', 'west-bengal']


for i in year:
    for j in Quarter:
        for k in states:
            a = df_maptrans.loc[(df_maptrans["Year"] == i) & (df_maptrans["Quarter"] == j) & (df_maptrans["State"] == k), 'Count'].sum()
            b = df_maptrans.loc[(df_maptrans["Year"] == i) & (df_maptrans["Quarter"] == j) & (df_maptrans["State"] == k),'amount'].sum()
            colb['Year'].append(i),
            colb['Quarter'].append(j),
            colb['State'].append(k)
            colb['Count'].append(a)
            colb['Amount'].append(b)
            
df_maptrans =pd.DataFrame(colb)
df_maptrans.to_csv('maptran.csv', index = False)

# %%
# Transforming map user data to required format

df_mapuser = pd.read_csv('map_user.csv')

colc = {'Year' : [], 'Quarter' : [], 'State' : [], 'Registered_User' : [], 'AppOpens' : []}

year = [2018, 2019, 2020, 2021, 2022]
Quarter = [1,2,3,4]
states = ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh',
                  'assam', 'bihar', 'chandigarh', 'chhattisgarh',
                  'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat',
                  'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand',
                  'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh',
                  'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland',
                  'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
                  'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh',
                  'uttarakhand', 'west-bengal']


for i in year:
    for j in Quarter:
        for k in states:
            a = df_mapuser.loc[(df_mapuser["Year"] == i) & (df_mapuser["Quarter"] == j) & (df_mapuser["State"] == k), 'Registered_User'].sum()
            b = df_mapuser.loc[(df_mapuser["Year"] == i) & (df_mapuser["Quarter"] == j) & (df_mapuser["State"] == k),'AppOnes'].sum()
            colc['Year'].append(i),
            colc['Quarter'].append(j),
            colc['State'].append(k)
            colc['Registered_User'].append(a)
            colc['AppOpens'].append(b)
            
df_mapuser =pd.DataFrame(colc)
df_mapuser.to_csv('mapuser.csv', index = False)

# %%
#Transforming Top Transcation data
df_toptrans = pd.read_csv('top_transaction.csv')

colg = {'Entity_Name': [], 'Year': [], 'Quarter': [], 'Type': [], 'Count': [],
        'Amount': [], 'State' : []}


states = ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh',
                  'assam', 'bihar', 'chandigarh', 'chhattisgarh',
                  'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat',
                  'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand',
                  'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh',
                  'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland',
                  'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
                  'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh',
                  'uttarakhand', 'west-bengal']
year = [2018, 2019, 2020, 2021, 2022]
Quarter = [1,2,3,4]

for i in year:
    for j in Quarter:
        for k in states:
            a = df_toptrans.loc[(df_toptrans['Year'] == i) & (df_toptrans['Quarter'] == j) & (df_toptrans['State'] == k) & (df_toptrans['Type'] == 'District') , 'Count'].sum()
            b = df_toptrans.loc[(df_toptrans['Year'] == i) & (df_toptrans['Quarter'] == j) & (df_toptrans['State'] == k) & (df_toptrans['Type'] == 'District') , 'Amount'].sum()
            colg['State'].append('--')
            colg['Type'].append('State')
            colg['Year'].append(i)
            colg['Quarter'].append(j)
            colg['Entity_Name'].append(k)
            colg['Count'].append(a)
            colg['Amount'].append(b)
            
            
df = pd.DataFrame(colg)
df.to_csv('top_transaction.csv', mode = 'a', index = False, header = False)

# %%
#Transforming Top user data
df_topuser = pd.read_csv('top_user.csv')

colx = {'Entity_Name': [], 'Year': [], 'Quarter': [], 'Type': [], 'Registered_User': [], 'State' : []}

states = ['andaman-&-nicobar-islands', 'andhra-pradesh', 'arunachal-pradesh',
                  'assam', 'bihar', 'chandigarh', 'chhattisgarh',
                  'dadra-&-nagar-haveli-&-daman-&-diu', 'delhi', 'goa', 'gujarat',
                  'haryana', 'himachal-pradesh', 'jammu-&-kashmir', 'jharkhand',
                  'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya-pradesh',
                  'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland',
                  'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
                  'tamil-nadu', 'telangana', 'tripura', 'uttar-pradesh',
                  'uttarakhand', 'west-bengal']
year = [2018, 2019, 2020, 2021, 2022]
Quarter = [1,2,3,4]

for i in year:
    for j in Quarter:
        for k in states:
            a = df_topuser.loc[(df_topuser['Year'] == i) & (df_topuser['Quarter'] == j) & (df_topuser['State'] == k) & (df_topuser['Type'] == 'District'), 'Registered_User'].sum()
            colx['State'].append('--')
            colx['Type'].append('State')
            colx['Year'].append(i)
            colx['Quarter'].append(j)
            colx['Entity_Name'].append(k)
            colx['Registered_User'].append(a)

                
df_topuser = pd.DataFrame(colx)
df_topuser.to_csv('top_user.csv', mode='a', index=False, header = False)

# %%
df_mobile = pd.read_csv('aggregateduser_mobile.csv')

col = {'Year':[], 'Quarter':[], 'Brand':[], 'Count':[], 'Percentage':[]}

brand = ['Xiaomi', 'Samsung', 'Vivo', 'Oppo', 'Realme', 'Apple', 'Motorola', 'Lenovo', 'Huawei', 'Others']
year = [2018, 2019, 2020, 2021, 2022]
Quarter = [1,2,3,4]

for i in year:
    for j in Quarter:
        for k in brand:
            a = df_mobile.loc[(df_mobile['Year'] == i) & (df_mobile['Quarter'] == j) & (df_mobile['Brands'] == k), 'Count'].sum()
            b = df_mobile.loc[(df_mobile['Year'] == i) & (df_mobile['Quarter'] == j) & (df_mobile['Brands'] == k), 'Percentage'].mean()
            col['Year'].append(i)
            col['Quarter'].append(j)
            col['Brand'].append(k)
            col['Count'].append(a)
            col['Percentage'].append(b)
df_mob = pd.DataFrame(col)
df_mob.to_csv('mobile.csv', index = False)

# %%
import mysql.connector
from mysql.connector import Error
from sqlalchemy import create_engine
import pandas as pd

# opening mysql using create engine module
mydb = create_engine("mysql+mysqlconnector://root:<password>@127.0.0.1:3306/phonepe_pulse")

config = { 'host' : 'localhost',
            'database' :'phonepe_pulse',
            'user' : "name",
           'password' : "abcd",
           'port' : 3306}

cursor = mysql.connector.connect(**config)

# checking connection
if cursor.is_connected():
    print('connected')
else:
    print('not connected')

# reading csv files and loading to mysql
df_aggregated_transaction = pd.read_csv('aggregated_transaction.csv')
df_aggregated_transaction.to_sql(con=mydb, name='aggregated_transaction', if_exists='replace', index=False)
df_aggrUser_mobile = pd.read_csv('aggregateduser_mobile.csv')
df_aggrUser_mobile.to_sql(con=mydb, name='aggregateduser_mobile', if_exists='replace', index=False)
df_aggruser = pd.read_csv('aggregated_user.csv')
df_aggruser.to_sql(con=mydb, name='aggregated_user', if_exists='replace', index=False)                          
df_map_transaction = pd.read_csv('map_transaction.csv')
df_map_transaction.to_sql(con=mydb, name='map_transaction', if_exists='replace', index=False)
df_map_user = pd.read_csv('map_user.csv')
df_map_user.to_sql(con=mydb, name='map_user', if_exists='replace', index=False)
df_top_transaction = pd.read_csv('top_transaction.csv')
df_top_transaction.to_sql(con=mydb, name='top_transaction', if_exists='replace', index=False)
df_top_user = pd.read_csv('top_user.csv')
df_top_user.to_sql(con=mydb, name='top_user', if_exists='replace', index=False)
df_aggtrans = pd.read_csv('aggtrans.csv')
df_aggtrans.to_sql(con=mydb, name='aggtrans', if_exists='replace', index=False)
df_agguser = pd.read_csv('agguser.csv')
df_agguser.to_sql(con=mydb, name='agguser', if_exists='replace', index=False)
df_maptran = pd.read_csv('maptran.csv')
df_maptran.to_sql(con=mydb, name='maptran', if_exists='replace', index=False)
df_mapuser = pd.read_csv('mapuser.csv')
df_mapuser.to_sql(con=mydb, name='mapuser', if_exists='replace', index=False)
df_mobile = pd.read_csv('mobile.csv')
df_mobile.to_sql(con=mydb, name='mobile', if_exists='replace', index=False)
# df_topuser = pd.read_csv('topuser.csv')
# df_topuser.to_sql(con=mydb, name='topuser', if_exists='replace', index=False)
# Out:
# connected
# 200

# %%
import mysql.connector
from mysql.connector import Error
from sqlalchemy import create_engine
import mysql.connector as msql
import webbrowser
import mysql.connector

# opening mysql using create engine module
# mydb = create_engine("mysql+mysqlconnector://root:<password>@127.0.0.1:3306/pulse")

conn =mysql.connector.connect(host = 'localhost',
            database = 'phonepe_pulse',
            user = "root",
           password = "<password>",
           port = 3306)

cursor = conn.cursor()
Entity_Name = []
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 1 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 2 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 3 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 4 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 1 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 2 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 3 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2018 AND Quarter = 4 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 1 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 2 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 3 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 4 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 1 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 2 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 3 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2019 AND Quarter = 4 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 1 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 2 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 3 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 4 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 1 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 2 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 3 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2020 AND Quarter = 4 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 1 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 2 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 3 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 4 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 1 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 2 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 3 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2021 AND Quarter = 4 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 1 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 2 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 3 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 4 AND Type = 'District' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 1 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 2 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 3 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_user WHERE Year = 2022 AND Quarter = 4 AND Type = 'State' ORDER BY Registered_User DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])

# %%
Entity_name = []
Year = []
Quarter = []
Type = []
Registered_User = []

for i in Entity_Name:
    Entity_name.append(i[0])
    Year.append(i[1])
    Quarter.append(i[2])
    Type.append(i[3])
    Registered_User.append(i[4])

df = pd.DataFrame({'Entity_Name' : Entity_name, 'Year' : Year , 'Quarter' : Quarter , 'Type' : Type , 'Registered_User' : Registered_User})
df.to_csv('topuser.csv', index = False)

# %%
df_topuser = pd.read_csv('topuser.csv')
df_topuser.to_sql(con=mydb, name='topuser', if_exists='replace', index=False)
# Out:
# 600

# %%
import mysql.connector
from mysql.connector import Error
from sqlalchemy import create_engine
import mysql.connector as msql
import webbrowser
import mysql.connector

# opening mysql using create engine module
# mydb = create_engine("mysql+mysqlconnector://root:<password>@127.0.0.1:3306/pulse")

conn =mysql.connector.connect(host = 'localhost',
            database = 'phonepe_pulse',
            user = "root",
           password = "<password>",
           port = 3306)

cursor = conn.cursor()
Entity_Name = []
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 1 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 2 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 3 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 4 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 1 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 2 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 3 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2018 AND Quarter = 4 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 1 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 2 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 3 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 4 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 1 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 2 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 3 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2019 AND Quarter = 4 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 1 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 2 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 3 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 4 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 1 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 2 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 3 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2020 AND Quarter = 4 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 1 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 2 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 3 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 4 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 1 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 2 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 3 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2021 AND Quarter = 4 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 1 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 2 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 3 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 4 AND Type = 'Pincode' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 1 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 2 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 3 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 4 AND Type = 'District' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 1 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 2 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 3 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])
query = f"SELECT * FROM phonepe_pulse.top_transaction WHERE Year = 2022 AND Quarter = 4 AND Type = 'State' ORDER BY Count DESC LIMIT 10"
cursor.execute(query)
records = cursor.fetchall()
for i in records:
    Entity_Name.append(i[0:])

# %%
import pandas as pd
Entity_name = []
Year = []
Quarter = []
Type = []
Registered_User = []

for i in Entity_Name:
    Entity_name.append(i[0])
    Year.append(i[1])
    Quarter.append(i[2])
    Type.append(i[3])
    Registered_User.append(i[4])

df = pd.DataFrame({'Entity_Name' : Entity_name, 'Year' : Year , 'Quarter' : Quarter , 'Type' : Type , 'Registered_User' : Registered_User})
df.to_csv('toptrans.csv', index = False)

# %%
import mysql.connector
from mysql.connector import Error
from sqlalchemy import create_engine

# opening mysql using create engine module
mydb = create_engine("mysql+mysqlconnector://root:<password>@127.0.0.1:3306/phonepe_pulse")

config = { 'host' : 'localhost',
            'database' :'phonepe_pulse',
            'user' : "root",
           'password' : "<password>",
           'port' : 3306}

cursor = mysql.connector.connect(**config)

df_topuser = pd.read_csv('toptrans.csv')
df_topuser.to_sql(con=mydb, name='toptrans', if_exists='replace', index=False)
# Out:
# 600
